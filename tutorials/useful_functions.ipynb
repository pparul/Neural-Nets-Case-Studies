# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
## Sigmoid

# %%
def sigmoid(x):
    sigmoid_func =  1/(1+ np.exp(-x))
    return sigmoid_func


def sigmoid_derivative(x):
    sigmoid_derivative_func = sigmoid(x) * (1-sigmoid(x))
    return sigmoid_derivative_func

# %%
y_d = sigmoid_derivative(0)
y_d
# Out:
# 0.25

# %%
x  = np.linspace(-10,10,1000)
y = sigmoid(x)
y_d = sigmoid_derivative(x)

plt.plot(x,y, color='red', label='Sigmoid Function')
plt.plot(x,y_d, color='green', label='Derivative of Sigmoid Function')
plt.grid()
plt.legend()
plt.xlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
## Logarithm Function

# %%
## Logarithm Loss Function

# %%
## categorical_crossentropy
