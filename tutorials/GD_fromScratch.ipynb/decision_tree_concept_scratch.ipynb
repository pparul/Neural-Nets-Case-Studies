# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# write a code for a basic decision tree from scratch

# %%
class Node():
    def __init__(self):
        self.feature_index = None
        self.threshold = None
        self.left = None
        self.right = None
        self.leaf_node = None

# %%
#Aleading underscore (_) in front of a function name is a widely used convention, particularly in 
# Python, indicating that the function is internal, private, or not intended to be used directly 
# by external code.

class DecisionTree(Node):

    def __init__(self):
        self.left_child = None
        self.right_child = None
        self.split_value = None
        self.value = None

    def gini_score(self, data, target):
        num_classes 
        gini_score = 1 -
       returns gini_score 

    def best_split_point (self, feature_set, dataset, min_samples):
        return self.split_value

    def create_node(self):
        pass

    
    def build_tree(self, feature_set, dataset):
        # stopping condition
        if len(dataset) < min_samples: # or depth .. whatever stopping is here
            pass

        split_point = self.split_point()
        
        # all data less than split_point are left
        node.left_child  = self.create_left_tree(split_point , dataset)

        # all data less than split_point are right
        node.left_child = self.create_right_tree(self.split_point, dataset)

        build_tree(feature_set, node.left_child)
        build_tree(feature_set, node.right_child)

# %%
## Final implementation
class Node():
    def __init__(self):
        self.feature_index = None
        self.threshold = None
        self.left = None
        self.right = None
        self.leaf_node = None


class Decision_Tree():
    def __init__(self, min_samples=10):
        self.min_samples = min_samples
        self.root = None

    def gini_score_calc(self, y):
        classes = np.unique(y)
        prob_c = 0
        for c in classes:
            p_c = np.sum(y==c)
            prob_c += (p_c/len(y))**2
        gini_score = 1 - prob_c
        return gini_score 

    # assuming X is an array 
    def best_split_point (self, X, y):
        best_gini = np.inf
        
        for feature_idx in range(X.shape[1]):
            for threshold in thresholds:
                left_data_idx = X[feature_idx,:] <= threshold
                right_data_idx = X[feature_idx,:] <= threshold

                left_gini = self.gini_score_calc(y[left_data_idx])
                right_gini = self.gini_score_calc(y[right_data_idx])

                # weighted_gini
                best_gini = 
                best_feature =  
                best_threshold = 


    def build_tree(self, X, y):
        # stopping condition
        if len(y) < self.min_samples: # or depth .. whatever stopping is here
            return Node

        best_feature, best_threshold = self.best_split_point (self, X, y)
        
        # split_data
        left_mask  = 
        right_mask = 

        # traverse children
        build_tree((X[left_mask], y[left_mask]))
        build_tree((X[right_mask], y[right_mask]))

        return Node()
